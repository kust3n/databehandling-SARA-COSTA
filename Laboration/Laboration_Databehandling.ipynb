# %% [markdown]
# # Laboration - Databehandling
#
# ### Uppgift A

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# a
college = pd.read_csv("College.csv")
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# ### Uppgift B

# %%
# b
college2 = pd.read_csv("College.csv", index_col=0)
college3 = college.rename ({"Unnamed: 0": "College"} , axis =1)
college3 = college3.set_index("College")

college = college3
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# ### Uppgift C

# %%
# c
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ### Uppgift D

# %%
# d
c = ["Top10perc", "Apps", "Enroll"]
pd.plotting.scatter_matrix(college[c])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# ### Uppgift E

# %%
# e
college.boxplot("Outstate", "Private")
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# ### Uppgift F

# %%
# f

college["Elite"] = pd.cut(college["Top10perc"], [0, 50, 100], labels=["No", "Yes"])

print(college["Elite"].value_counts())

college.boxplot("Outstate", "Elite")
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# ### Uppgift G

# %%
# g
#q_variables = ["Apps", "Accept", "Enroll", "Grad.Rate"]

fig, axes = plt.subplots(2, 2, figsize=(10,8))

college["Apps"].plot.hist(bins=20, ax=axes[0,0], title="Applications")
college["Apps"].plot.hist(bins=100, ax=axes[1,0], title="Applications")

college["Accept"].plot.hist(bins=30, ax=axes[0,1], title="Accepted applicants")
college["Accept"].plot.hist(bins=100, ax=axes[1,1], title="Accepted applicants")
# Out:
# <Axes: title={'center': 'Accepted applicants'}, ylabel='Frequency'>

# %% [markdown]
# ### Uppgift H
#
# ### *Continue exploring the data, and provide a brief summary of what you discover. Describe what you are looking for and what you find. For example, are there any correlations between personal spending, instructional spending and Elite status?*
#
# Jag ska fortsätta utforska lite av datan och jämföra olika punkter tillsammans med sammanfattning och tankar. Jag valde att jämföra följande:
#
# *  Student/Faculty Ratio versus Graduation Rate. Elite schools marked
#
# *  Alumni donations by Elite and non-Elite schools
#
# *  Percent of Ph.D.s in Elite and non-Elite schools
#
# *  New students from Top 10 in Elite and non-Elite

# %%
sns.scatterplot(x='S.F.Ratio', y='Grad.Rate', hue='Elite', data=college)
plt.title("Student/Faculty Ratio versus Grad. Rate")
# Out:
# Text(0.5, 1.0, 'Student/Faculty Ratio versus Grad. Rate')

# %%
sns.boxplot(x="Elite", y="perc.alumni", hue="Elite", data=college)
plt.title("Alumni donations by Elite")
# Out:
# Text(0.5, 1.0, 'Alumni donations by Elite')

# %%
sns.barplot(x="Elite", y="PhD", hue="Elite", data=college)
plt.title("Percent of Ph.D.s in Elite and non-Elite")
# Out:
# Text(0.5, 1.0, 'Percent of Ph.D.s in Elite and non-Elite')

# %%
sns.boxplot(x="Elite", y="Top10perc", hue="Elite", data=college)
plt.title("New students from top 10 in Elite and non-Elite")
# Out:
# Text(0.5, 1.0, 'New students from top 10 in Elite and non-Elite')

# %% [markdown]
# ## Utvärdering
